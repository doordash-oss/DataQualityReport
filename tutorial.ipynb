# %% [markdown]
# # Data Quality Report Tutorial

# %%
import pandas as pd
import numpy as np
from dataqualityreport import dqr_table, DataQualityReport

# %%
df = pd.read_csv('tests/ds_salaries.csv', index_col=0)

# %%
# The following modifications are made ONLY TO ILLUSTRATE FUNCTIONALITY in the tutorial

# Create a partition column
df.loc[:, 'active_date'] = np.random.choice(a=range(5), size=len(df))

# Add some missing values
df.loc[df.active_date == 1, df.columns[[3,7]]] = np.nan

# %% [markdown]
# ## Generating a DataQualityReport table
#
# All 2-D DataFrames containing scalar values in each cell should be supported; No processing of columns is required.

# %%
dqr_table(df)
# Out:
# Building summary df...
# Constructing box plots...
# Spreading hist plots...
# Building missing_by plots...
# <style type="text/css">
# #T_b869e_ th {
#   font-weight: normal;
# }
# #T_b869e_ .col_heading {
#   text-align: center;
# }
# #T_b869e_ .level0.index_name {
#   text-align: left;
# }
# #T_b869e_ .level0.row_heading {
#   text-align: left;
# }
# #T_b869e_ tr {
#   background-color: white;
# }
# #T_b869e_ tbody tr:hover {
#   background-color: #ededed;
# }
# #T_b869e_row0_col0, #T_b869e_row0_col1, #T_b869e_row0_col2, #T_b869e_row0_col3, #T_b869e_row0_col4, #T_b869e_row0_col5, #T_b869e_row0_col6, #T_b869e_row0_col7, #T_b869e_row0_col8, #T_b869e_row1_col0, #T_b869e_row1_col1, #T_b869e_row1_col2, #T_b869e_row1_col3, #T_b869e_row1_col4, #T_b869e_row1_col5, #T_b869e_row1_col6, #T_b869e_row1_col7, #T_b869e_row1_col8, #T_b869e_row2_col0, #T_b869e_row2_col1, #T_b869e_row2_col2, #T_b869e_row2_col3, #T_b869e_row2_col4, #T_b869e_row2_col5, #T_b869e_row2_col6, #T_b869e_row2_col7, #T_b869e_row2_col8, #T_b869e_row3_col0, #T_b869e_row3_col1, #T_b869e_row3_col2, #T_b869e_row3_col3, #T_b869e_row3_col4, #T_b869e_row3_col5, #T_b869e_row3_col6, #T_b869e_row3_col7, #T_b869e_row3_col8, #T_b869e_row4_col0, #T_b869e_row4_col1, #T_b869e_row4_col2, #T_b869e_row4_col3, #T_b869e_row4_col4, #T_b869e_row4_col5, #T_b869e_row4_col6, #T_b869e_row4_col7, #T_b869e_row4_col8, #T_b869e_row5_col0, #T_b869e_row5_col1, #T_b869e_row5_col2, #T_b869e_row5_col3, #T_b869e_row5_col4, #T_b869e_row5_col5, #T_b869e_row5_col6, #T_b869e_row5_col7, #T_b869e_row5_col8, #T_b869e_row6_col0, #T_b869e_row6_col1, #T_b869e_row6_col2, #T_b869e_row6_col3, #T_b869e_row6_col4, #T_b869e_row6_col5, #T_b869e_row6_col6, #T_b869e_row6_col7, #T_b869e_row6_col8, #T_b869e_row7_col0, #T_b869e_row7_col1, #T_b869e_row7_col2, #T_b869e_row7_col3, #T_b869e_row7_col4, #T_b869e_row7_col5, #T_b869e_row7_col6, #T_b869e_row7_col7, #T_b869e_row7_col8, #T_b869e_row8_col0, #T_b869e_row8_col1, #T_b869e_row8_col2, #T_b869e_row8_col3, #T_b869e_row8_col4, #T_b869e_row8_col5, #T_b869e_row8_col6, #T_b869e_row8_col7, #T_b869e_row8_col8, #T_b869e_row9_col0, #T_b869e_row9_col1, #T_b869e_row9_col2, #T_b869e_row9_col3, #T_b869e_row9_col4, #T_b869e_row9_col5, #T_b869e_row9_col6, #T_b869e_row9_col7, #T_b869e_row9_col8, #T_b869e_row10_col0, #T_b869e_row10_col1, #T_b869e_row10_col2, #T_b869e_row10_col3, #T_b869e_row10_col4, #T_b869e_row10_col5, #T_b869e_row10_col6, #T_b869e_row10_col7, #T_b869e_row10_col8, #T_b869e_row11_col0, #T_b869e_row11_col1, #T_b869e_row11_col2, #T_b869e_row11_col3, #T_b869e_row11_col4, #T_b869e_row11_col5, #T_b869e_row11_col6, #T_b869e_row11_col7, #T_b869e_row11_col8 {
#   text-align: center;
#   width: fit-content;
#   height: fit-content;
#   padding-top: 2px;
#   padding-bottom: 2px;
# }
# </style>
# <table id="T_b869e_">
#   <caption>607 rows by 12 columns</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Type</th>
#       <th class="col_heading level0 col1" ><div title='Cardinality (# of unique elements)
# * -> Unique (Cardinality = Row Count)'>Card<br>*Unique</div></th>
#       <th class="col_heading level0 col2" >% Missing<br>Partition</th>
#       <th class="col_heading level0 col3" >% Missing<br>Heatmap</th>
#       <th class="col_heading level0 col4" >%<br>Missing</th>
#       <th class="col_heading level0 col5" >%<br>Zeros</th>
#       <th class="col_heading level0 col6" >%<br>Negative</th>
#       <th class="col_heading level0 col7" >Box Plot</th>
#       <th class="col_heading level0 col8" >Robust Histogram</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b869e_level0_row0" class="row_heading level0 row0" >work_year</th>
#       <td id="T_b869e_row0_col0" class="data row0 col0" ><div title='int64'>I</div></td>
#       <td id="T_b869e_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_b869e_row0_col2" class="data row0 col2" ><img src="..."/></td>
#       <td id="T_b869e_row0_col3" class="data row0 col3" ></td>
#       <td id="T_b869e_row0_col4" class="data row0 col4" ><div title='0.00% missing'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row0_col5" class="data row0 col5" ><div title='0.00% zeros'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row0_col6" class="data row0 col6" ><div title='0.00% negative'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row0_col7" class="data row0 col7" ><div title='min: 2020.0
# num_low_10x_IQR_outliers: 0.0
# num_low_3x_IQR_outliers: 0.0
# p05: 2020.0
# p25: 2021.0
# median: 2022.0
# mean: 2021.4052718286655
# p75: 2022.0
# p95: 2022.0
# num_high_3x_IQR_outliers: 0.0
# num_high_10x_IQR_outliers: 0.0
# max: 2022.0'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row0_col8" class="data row0 col8" ><div title='val_most_freq: 2022
# perc_most_freq: 0.5238879736408567'><img src="..."/></div></td>
#     </tr>
#     <tr>
#       <th id="T_b869e_level0_row1" class="row_heading level0 row1" >experience_level</th>
#       <td id="T_b869e_row1_col0" class="data row1 col0" ><div title='object'>O</div></td>
#       <td id="T_b869e_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_b869e_row1_col2" class="data row1 col2" ><img src="..."/></td>
#       <td id="T_b869e_row1_col3" class="data row1 col3" ></td>
#       <td id="T_b869e_row1_col4" class="data row1 col4" ><div title='0.00% missing'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row1_col5" class="data row1 col5" ><div title='-100.00% zeros'><img src="..."/></div></td>
#       <td id="T_b869e_row1_col6" class="data row1 col6" ><div title='-100.00% negative'><img src="..."/></div></td>
#       <td id="T_b869e_row1_col7" class="data row1 col7" ><div title='min: nan
# num_low_10x_IQR_outliers: nan
# num_low_3x_IQR_outliers: nan
# p05: nan
# p25: nan
# median: nan
# mean: nan
# p75: nan
# p95: nan
# num_high_3x_IQR_outliers: nan
# num_high_10x_IQR_outliers: nan
# max: nan'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row1_col8" class="data row1 col8" ><div title='val_most_freq: SE
# perc_most_freq: 0.4612850082372323'><img src="..."/></div></td>
#     </tr>
#     <tr>
#       <th id="T_b869e_level0_row2" class="row_heading level0 row2" >employment_type</th>
#       <td id="T_b869e_row2_col0" class="data row2 col0" ><div title='object'>O</div></td>
#       <td id="T_b869e_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_b869e_row2_col2" class="data row2 col2" ><img src="..."/></td>
#       <td id="T_b869e_row2_col3" class="data row2 col3" ></td>
#       <td id="T_b869e_row2_col4" class="data row2 col4" ><div title='0.00% missing'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row2_col5" class="data row2 col5" ><div title='-100.00% zeros'><img src="..."/></div></td>
#       <td id="T_b869e_row2_col6" class="data row2 col6" ><div title='-100.00% negative'><img src="..."/></div></td>
#       <td id="T_b869e_row2_col7" class="data row2 col7" ><div title='min: nan
# num_low_10x_IQR_outliers: nan
# num_low_3x_IQR_outliers: nan
# p05: nan
# p25: nan
# median: nan
# mean: nan
# p75: nan
# p95: nan
# num_high_3x_IQR_outliers: nan
# num_high_10x_IQR_outliers: nan
# max: nan'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_b869e_row2_col8" class="data row2 col8" ><div title='val_most_freq: FT
# perc_most_freq: 0.9686985172981878'><img src="..."/></div></td>
#     </tr>
#     <tr>
#       <th id="T_b869e_level0_row3" class="row_heading level0 row3" >job_title</th>
#       <td id="T_b869e_row3_col0" class="data row3 col0" ><div title='object'>O</div></td>
#       <td id="T_b869e_row3_col1" class="data row3 col1" >48</td>
#       <td id="T_b869e_row3_col2" class="data row3 col2" ><img src="..."/></td>
#       <td id="T_b869e

# %% [markdown]
# ## Understanding DQR Tables
#
# DQR tables summarize data statistics for each column in a Pandas DataFrame. Each column is represented in a separate row. No general cross-column statistics (e.g. correlations) are computed, although there is a specific 'partition' column that has some unique treatments.
#
# The fields in the DQR table are defined below. Many fields have tooltips with additional data available on hover.
#
# ### Type
# DataType (Pandas DType) of the column
#
# ### Card(inality)
# Number of unique non-NULL values in the column. Unique fields (where each non-null entry is distinct) will be denoted by a *.
#
# ### % Missing Partition
# The DataFrame is partitioned by the column name provided in the `missing_by` parameter (`active_date` by default if it exists). <br> A missing % is computed for each partition and rendered as a 1-D heatmap / bar chart.
#
# Datasets collected from production systems through ETL processes often use [horizontal](https://en.wikipedia.org/wiki/Partition_(database)) partitions as a unit of dataset for adding, updates or removal. Upon ETL failures, often times entire individual partitions can be missing, or a subset of fields will be missing for a portion of the partition.
#
# ### % Missing Heatmap
# A subset of table is randomly partitioned and a missing % is computed for each partition and rendered as a 1-D heatmap. This is useful to see correlations between missing values across columns.
#
# ### % Missing
# The % of missing (null) values in the column.
#
# ### % Zeros
# % of values that are zero (only valid for numeric columns)
#
# ### % Negative
# % of values that are negative
#
# ### Box Plot
# A [boxplot](https://en.wikipedia.org/wiki/Box_plot) is a standardized way of displaying the dataset based on the five-number summary: the minimum, the maximum, the sample median, and the first and third quartiles.
#
# ### Robust Histogram
# A robust [histogram](https://en.wikipedia.org/wiki/Histogram) is an approximate representation of the distribution of numerical data, where outliers have been removed using the IQR (Inter-quantile range) method.

# %% [markdown]
# ## Compare Two Dataframes
# You can create DataQualityReports comparing N similar dataframes.  While they do not need to share all column names, `DQR_compare` will align axes for the histogram and box charts for columns that are shared in the different dataframes

# %%
df_train=df.sample(frac=0.8,random_state=200).iloc[:, 0:5] #random state is a seed value
df_eval=df.drop(df_train.index).iloc[:, 0:5]
print(f'df_train rows:{len(df_train)}; df_eval rows:{len(df_eval)}')

from dataqualityreport.dataqualityreport import dqr_compare
dqr_compare([df_train, df_eval], suffixes=['train', 'eval'])
# Out:
# df_train rows:486; df_eval rows:121
# Building summary df...
# Constructing box plots...
# Spreading hist plots...
# Building summary df...
# Constructing box plots...
# Spreading hist plots...
# <style type="text/css">
# #T_d8836_ th {
#   font-weight: normal;
# }
# #T_d8836_ .col_heading {
#   text-align: center;
# }
# #T_d8836_ .level0.index_name {
#   text-align: left;
# }
# #T_d8836_ .level0.row_heading {
#   text-align: left;
# }
# #T_d8836_ tr {
#   background-color: white;
# }
# #T_d8836_ tbody tr:hover {
#   background-color: #ededed;
# }
# #T_d8836_row0_col0, #T_d8836_row0_col1, #T_d8836_row0_col2, #T_d8836_row0_col3, #T_d8836_row0_col4, #T_d8836_row0_col5, #T_d8836_row0_col6, #T_d8836_row0_col7, #T_d8836_row1_col0, #T_d8836_row1_col1, #T_d8836_row1_col2, #T_d8836_row1_col3, #T_d8836_row1_col4, #T_d8836_row1_col5, #T_d8836_row1_col6, #T_d8836_row1_col7, #T_d8836_row2_col0, #T_d8836_row2_col1, #T_d8836_row2_col2, #T_d8836_row2_col3, #T_d8836_row2_col4, #T_d8836_row2_col5, #T_d8836_row2_col6, #T_d8836_row2_col7, #T_d8836_row3_col0, #T_d8836_row3_col1, #T_d8836_row3_col2, #T_d8836_row3_col3, #T_d8836_row3_col4, #T_d8836_row3_col5, #T_d8836_row3_col6, #T_d8836_row3_col7, #T_d8836_row4_col0, #T_d8836_row4_col1, #T_d8836_row4_col2, #T_d8836_row4_col3, #T_d8836_row4_col4, #T_d8836_row4_col5, #T_d8836_row4_col6, #T_d8836_row4_col7, #T_d8836_row5_col0, #T_d8836_row5_col1, #T_d8836_row5_col2, #T_d8836_row5_col3, #T_d8836_row5_col4, #T_d8836_row5_col5, #T_d8836_row5_col6, #T_d8836_row5_col7, #T_d8836_row6_col0, #T_d8836_row6_col1, #T_d8836_row6_col2, #T_d8836_row6_col3, #T_d8836_row6_col4, #T_d8836_row6_col5, #T_d8836_row6_col6, #T_d8836_row6_col7, #T_d8836_row7_col0, #T_d8836_row7_col1, #T_d8836_row7_col2, #T_d8836_row7_col3, #T_d8836_row7_col4, #T_d8836_row7_col5, #T_d8836_row7_col6, #T_d8836_row7_col7, #T_d8836_row8_col0, #T_d8836_row8_col1, #T_d8836_row8_col2, #T_d8836_row8_col3, #T_d8836_row8_col4, #T_d8836_row8_col5, #T_d8836_row8_col6, #T_d8836_row8_col7, #T_d8836_row9_col0, #T_d8836_row9_col1, #T_d8836_row9_col2, #T_d8836_row9_col3, #T_d8836_row9_col4, #T_d8836_row9_col5, #T_d8836_row9_col6, #T_d8836_row9_col7 {
#   text-align: center;
#   width: fit-content;
#   height: fit-content;
#   padding-top: 2px;
#   padding-bottom: 2px;
# }
# </style>
# <table id="T_d8836_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Type</th>
#       <th class="col_heading level0 col1" ><div title='Cardinality (# of unique elements)
# * -> Unique (Cardinality = Row Count)'>Card<br>*Unique</div></th>
#       <th class="col_heading level0 col2" >% Missing<br>Heatmap</th>
#       <th class="col_heading level0 col3" >%<br>Missing</th>
#       <th class="col_heading level0 col4" >%<br>Zeros</th>
#       <th class="col_heading level0 col5" >%<br>Negative</th>
#       <th class="col_heading level0 col6" >Box Plot</th>
#       <th class="col_heading level0 col7" >Robust Histogram</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8836_level0_row0" class="row_heading level0 row0" >employment_type-eval</th>
#       <td id="T_d8836_row0_col0" class="data row0 col0" ><div title='object'>O</div></td>
#       <td id="T_d8836_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_d8836_row0_col2" class="data row0 col2" ></td>
#       <td id="T_d8836_row0_col3" class="data row0 col3" ><div title='0.00% missing'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row0_col4" class="data row0 col4" ><div title='-100.00% zeros'><img src="..."/></div></td>
#       <td id="T_d8836_row0_col5" class="data row0 col5" ><div title='-100.00% negative'><img src="..."/></div></td>
#       <td id="T_d8836_row0_col6" class="data row0 col6" ><div title='min: nan
# num_low_10x_IQR_outliers: nan
# num_low_3x_IQR_outliers: nan
# p05: nan
# p25: nan
# median: nan
# mean: nan
# p75: nan
# p95: nan
# num_high_3x_IQR_outliers: nan
# num_high_10x_IQR_outliers: nan
# max: nan'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row0_col7" class="data row0 col7" ><div title='val_most_freq: FT
# perc_most_freq: 0.9586776859504132'><img src="..."/></div></td>
#     </tr>
#     <tr>
#       <th id="T_d8836_level0_row1" class="row_heading level0 row1" >employment_type-train</th>
#       <td id="T_d8836_row1_col0" class="data row1 col0" ><div title='object'>O</div></td>
#       <td id="T_d8836_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_d8836_row1_col2" class="data row1 col2" ></td>
#       <td id="T_d8836_row1_col3" class="data row1 col3" ><div title='0.00% missing'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row1_col4" class="data row1 col4" ><div title='-100.00% zeros'><img src="..."/></div></td>
#       <td id="T_d8836_row1_col5" class="data row1 col5" ><div title='-100.00% negative'><img src="..."/></div></td>
#       <td id="T_d8836_row1_col6" class="data row1 col6" ><div title='min: nan
# num_low_10x_IQR_outliers: nan
# num_low_3x_IQR_outliers: nan
# p05: nan
# p25: nan
# median: nan
# mean: nan
# p75: nan
# p95: nan
# num_high_3x_IQR_outliers: nan
# num_high_10x_IQR_outliers: nan
# max: nan'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row1_col7" class="data row1 col7" ><div title='val_most_freq: FT
# perc_most_freq: 0.9711934156378601'><img src="..."/></div></td>
#     </tr>
#     <tr>
#       <th id="T_d8836_level0_row2" class="row_heading level0 row2" >experience_level-eval</th>
#       <td id="T_d8836_row2_col0" class="data row2 col0" ><div title='object'>O</div></td>
#       <td id="T_d8836_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_d8836_row2_col2" class="data row2 col2" ></td>
#       <td id="T_d8836_row2_col3" class="data row2 col3" ><div title='0.00% missing'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row2_col4" class="data row2 col4" ><div title='-100.00% zeros'><img src="..."/></div></td>
#       <td id="T_d8836_row2_col5" class="data row2 col5" ><div title='-100.00% negative'><img src="..."/></div></td>
#       <td id="T_d8836_row2_col6" class="data row2 col6" ><div title='min: nan
# num_low_10x_IQR_outliers: nan
# num_low_3x_IQR_outliers: nan
# p05: nan
# p25: nan
# median: nan
# mean: nan
# p75: nan
# p95: nan
# num_high_3x_IQR_outliers: nan
# num_high_10x_IQR_outliers: nan
# max: nan'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row2_col7" class="data row2 col7" ><div title='val_most_freq: SE
# perc_most_freq: 0.4049586776859504'><img src="..."/></div></td>
#     </tr>
#     <tr>
#       <th id="T_d8836_level0_row3" class="row_heading level0 row3" >experience_level-train</th>
#       <td id="T_d8836_row3_col0" class="data row3 col0" ><div title='object'>O</div></td>
#       <td id="T_d8836_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_d8836_row3_col2" class="data row3 col2" ></td>
#       <td id="T_d8836_row3_col3" class="data row3 col3" ><div title='0.00% missing'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row3_col4" class="data row3 col4" ><div title='-100.00% zeros'><img src="..."/></div></td>
#       <td id="T_d8836_row3_col5" class="data row3 col5" ><div title='-100.00% negative'><img src="..."/></div></td>
#       <td id="T_d8836_row3_col6" class="data row3 col6" ><div title='min: nan
# num_low_10x_IQR_outliers: nan
# num_low_3x_IQR_outliers: nan
# p05: nan
# p25: nan
# median: nan
# mean: nan
# p75: nan
# p95: nan
# num_high_3x_IQR_outliers: nan
# num_high_10x_IQR_outliers: nan
# max: nan'><img src="data:image/png;base64,..."/></div></td>
#       <td id="T_d8836_row3_col7" class="data row3 col7" ><div title='val_most_freq: SE
# perc_most_freq: 0.47530864197530864'><img src="..."/></div></td>
#     </tr>
#     <tr>
#       <th id="T_d8836_level0_row4" class="row_heading level0 row4" >job_title-eval</th>
#       <td id="T_d8836_row4_col0" class="data row4 col0" ><div title='object'>O</div></td>
#       <td id="T_d8836_

# %% [markdown]
# ## DataQualityReport Rules Engine
# `DataQualityReport`s use rules to define what is acceptable in terms of data quality and
# how severe data quality issues are.
#
# An example of a rule would be:
# > _Warn on missing >10% of entries for a column_
#
# Rules provide a **severity** level:
#
# - 0 is most severe,
# - 1 moderately severe,
# - ...
#
#
#
# **Severity** can depend a lot on context - values used in linear regression must be cleaner than GBDTs, and values of the target need to be cleaner that those of features. You should consider what rules make sense for you and apply them (more on this below) - but for now, you can assume that our default rules will give you some basic useful info.
#
# ## Text Reports
# The most basic output for the DataQualityReport is the text report, which is show when you try to `print` the object. It currently contains two main sections:
#
# 1) Summary counts of warnings by severity
#
# > ```
# S2:3, S3:10
# > ```
#
# This indicates there are 3 `S2`-level warnings, and 10 `S3`-level warnings
#
# 2) Warnings List
#
# > ```
# DataQualityWarning(level=2, field='LemasPctOfficDrugUn', msg='perc_zeros: 0.845035')
# DataQualityWarning(level=2, field='NumInShelters', msg='perc_zeros: 0.544132')
# DataQualityWarning(level=2, field='NumStreet', msg='perc_zeros: 0.725677')
# ...
# > ```
#
# The warnings list gives detail about each warning generated, including which field it pertains to, and metrics that led to the warning.

# %%
from dataqualityreport import DataQualityReport
dqr = DataQualityReport(df)
dqr
# Out:
# Building summary df...
# Data Quality Report
# S0:2, S2:2, S3:3
# DataQualityWarning(level=0, field='employee_residence', msg='num_missing_partitions: 1, min_missing_partition: 1, max_missing_partition: 1')
# DataQualityWarning(level=0, field='job_title', msg='num_missing_partitions: 1, min_missing_partition: 1, max_missing_partition: 1')
# DataQualityWarning(level=2, field='company_location', msg='High percentage of a single value perc_most_freq: 0.5848434925864909, val_most_freq: US')
# DataQualityWarning(level=2, field='employee_residence', msg='High percentage of a single value perc_most_freq: 0.5594989561586639, val_most_freq: US')
# DataQualityWarning(level=3, field='employee_residence', msg='perc_missing: 0.2108731466227347')
# DataQualityWarning(level=3, field='job_title', msg='perc_missing: 0.2108731466227347')
# DataQualityWarning(level=3, field='salary', msg='num_high_10x_IQR_outliers: 21, p75: 165000, p95: 450000, max: 3.04e+07')

# %% [markdown]
# ### Tell me your rules

# %%
dqr.rules
# Out:
# [DataQualityRule(level=0, condition='perc_missing > 0.95', fields=['perc_missing'], msg=''),
#  DataQualityRule(level=0, condition='n_unique==1', fields=['n_unique', 'mean'], msg=''),
#  DataQualityRule(level=0, condition='(num_missing_partitions > 0)', fields=['num_missing_partitions', 'min_missing_partition', 'max_missing_partition'], msg=''),
#  DataQualityRule(level=1, condition='(perc_distinct > 0.99) & (perc_distinct < 1)', fields=['perc_distinct'], msg=''),
#  DataQualityRule(level=1, condition='(perc_negative > 0) & (perc_negative < 0.05)', fields=['perc_negative', 'num_negative', 'min'], msg=''),
#  DataQualityRule(level=2, condition='(perc_zeros > 0.5)', fields=['perc_zeros'], msg=''),
#  DataQualityRule(level=2, condition="dtype == 'object'", fields=['dtype'], msg=''),
#  DataQualityRule(level=2, condition='(perc_missing > 0.5) & (perc_missing <= 0.95)', fields=['perc_missing'], msg=''),
#  DataQualityRule(level=2, condition='((n_unique > 30) | decimal_col) & (perc_most_freq > 0.4)', fields=['perc_most_freq', 'val_most_freq'], msg='High percentage of a single value'),
#  DataQualityRule(level=3, condition='(num_low_10x_IQR_outliers > 0)', fields=['min', 'p05', 'p25', 'num_low_10x_IQR_outliers'], msg=''),
#  DataQualityRule(level=3, condition='(num_high_10x_IQR_outliers > 0)', fields=['num_high_10x_IQR_outliers', 'p75', 'p95', 'max'], msg=''),
#  DataQualityRule(level=3, condition='(perc_missing > 0) & (perc_missing <= 0.5)', fields=['perc_missing'], msg='')]

# %% [markdown]
# ### Only get warnings worse than S2 (e.g. S2, S1, S0)

# %%
print(dqr.warnings_report_str(min_dq_level=2))
# Out:
# Data Quality Report
# S0:2, S2:2
# DataQualityWarning(level=0, field='employee_residence', msg='num_missing_partitions: 1, min_missing_partition: 1, max_missing_partition: 1')
# DataQualityWarning(level=0, field='job_title', msg='num_missing_partitions: 1, min_missing_partition: 1, max_missing_partition: 1')
# DataQualityWarning(level=2, field='company_location', msg='High percentage of a single value perc_most_freq: 0.5848434925864909, val_most_freq: US')
# DataQualityWarning(level=2, field='employee_residence', msg='High percentage of a single value perc_most_freq: 0.5594989561586639, val_most_freq: US')

# %% [markdown]
# ### Write my own rules
# Here, we lower the threshold for perc_zeros to 10%, and get more warnings.

# %%
from dataqualityreport.dataqualityreport import DataQualityRule
DataQualityReport(df, rules = [
    DataQualityRule(level=2, condition='(perc_zeros > 0.1)', fields=['perc_zeros'], msg=''),
    DataQualityRule(level=2, condition="dtype == 'object'", fields=['dtype'], msg=''),
    DataQualityRule(level=2, condition='(perc_missing > 0.3) & (perc_missing <= 0.95)', 
                    fields=['perc_missing'], msg='')])
# Out:
# Building summary df...
# Data Quality Report
# S2:2
# DataQualityWarning(level=2, field='active_date', msg='perc_zeros: 0.19769357495881384')
# DataQualityWarning(level=2, field='remote_ratio', msg='perc_zeros: 0.20922570016474465')

# %% [markdown]
# ### Rules reference values defined in the summary_df

# %%
dqr.summary_df.T
# Out:
#                                             work_year  \
# perc_missing                                      0.0
# perc_zeros                                        0.0
# num_negative                                      0.0
# num_zeros                                         0.0
# perc_negative                                     0.0
# perc_distinct                                0.004942
# num_low_3x_IQR_outliers                           0.0
# num_high_3x_IQR_outliers                          0.0
# num_low_10x_IQR_outliers                          0.0
# num_high_10x_IQR_outliers                         0.0
# count                                             607
# n_unique                                            3
# decimal_col                                     False
# perc_most_freq                               0.523888
# val_most_freq                                    2022
# min                                            2020.0
# p05                                            2020.0
# p25                                            2021.0
# median                                         2022.0
# mean                                      2021.405272
# p75                                            2022.0
# p95                                            2022.0
# max                                            2022.0
# dtype                      <div title='int64'>I</div>
# skew                                              NaN
# min_missing_partition                             NaN
# max_missing_partition                             NaN
# num_missing_partitions                            0.0
#
#                                       experience_level  \
# perc_missing                                       0.0
# perc_zeros                                         NaN
# num_negative                                       NaN
# num_zeros                                          NaN
# perc_negative                                      NaN
# perc_distinct                                  0.00659
# num_low_3x_IQR_outliers                            NaN
# num_high_3x_IQR_outliers                           NaN
# num_low_10x_IQR_outliers                           NaN
# num_high_10x_IQR_outliers                          NaN
# count                                              607
# n_unique                                             4
# decimal_col                                      False
# perc_most_freq                                0.461285
# val_most_freq                                       SE
# min                                                NaN
# p05                                                NaN
# p25                                                NaN
# median                                             NaN
# mean                                               NaN
# p75                                                NaN
# p95                                                NaN
# max                                                NaN
# dtype                      <div title='object'>O</div>
# skew                                               NaN
# min_missing_partition                              NaN
# max_missing_partition                              NaN
# num_missing_partitions                             0.0
#
#                                        employment_type  \
# perc_missing                                       0.0
# perc_zeros                                         NaN
# num_negative                                       NaN
# num_zeros                                          NaN
# perc_negative                                      NaN
# perc_distinct                                  0.00659
# num_low_3x_IQR_outliers                            NaN
# num_high_3x_IQR_outliers                           NaN
# num_low_10x_IQR_outliers                           NaN
# num_high_10x_IQR_outliers                          NaN
# count                                              607
# n_unique                                             4
# decimal_col                                      False
# perc_most_freq                                0.968699
# val_most_freq                                       FT
# min                                                NaN
# p05                                                NaN
# p25                                                NaN
# median                                             NaN
# mean                                               NaN
# p75                                                NaN
# p95                                                NaN
# max                                                NaN
# dtype                      <div title='object'>O</div>
# skew                                               NaN
# min_missing_partition                              NaN
# max_missing_partition                              NaN
# num_missing_partitions                             0.0
#
#                                              job_title  \
# perc_missing                                  0.210873
# perc_zeros                                         NaN
# num_negative                                       NaN
# num_zeros                                          NaN
# perc_negative                                      NaN
# perc_distinct                                 0.100209
# num_low_3x_IQR_outliers                            NaN
# num_high_3x_IQR_outliers                           NaN
# num_low_10x_IQR_outliers                           NaN
# num_high_10x_IQR_outliers                          NaN
# count                                              479
# n_unique                                            48
# decimal_col                                      False
# perc_most_freq                                0.235908
# val_most_freq                            Data Engineer
# min                                                NaN
# p05                                                NaN
# p25                                                NaN
# median                                             NaN
# mean                                               NaN
# p75                                                NaN
# p95                                                NaN
# max                                                NaN
# dtype                      <div title='object'>O</div>
# skew                                               NaN
# min_missing_partition                              1.0
# max_missing_partition                              1.0
# num_missing_partitions                             1.0
#
#                                                salary  \
# perc_missing                                      0.0
# perc_zeros                                        0.0
# num_negative                                      0.0
# num_zeros                                         0.0
# perc_negative                                     0.0
# perc_distinct                                0.448105
# num_low_3x_IQR_outliers                           0.0
# num_high_3x_IQR_outliers                         26.0
# num_low_10x_IQR_outliers                          0.0
# num_high_10x_IQR_outliers                        21.0
# count                                             607
# n_unique                                          272
# decimal_col                                     False
# perc_most_freq                               0.029654
# val_most_freq                                   80000
# min                                            4000.0
# p05                                           30000.0
# p25                                           70000.0
# median                                       115000.0
# mean                                    324000.062603
# p75                                          165000.0
# p95                                          450000.0
# max                                        30400000.0
# dtype                      <div title='int64'>I</div>
# skew                                        14.052915
# min_missing_partition                             NaN
# max_missing_partition                             NaN
# num_missing_partitions                            0.0
#
#                                        salary_currency  \
# perc_missing                                       0.0
# perc_zeros                                         NaN
# num_negative                                       NaN
# num_zeros                                          NaN
# perc_negative                                      NaN
# perc_distinct                                 0.028007
# num_low_3x_IQR_outliers                            NaN
# num_high_3x_IQR_outliers                           NaN
# num_low_10x_IQR_outliers                           NaN
# num_high_10x_IQR_outliers                          NaN
# count                                              607
# n_unique                                            17
# decimal_col                                      False
# perc_most_freq                                0.655684
# val_most_freq                                      USD
# min                                                NaN
# p05                                                NaN
# p25                                                NaN
# median                                             NaN
# mean                                               NaN
# p75                                                NaN
# p95                                                NaN
# max                                                NaN
# dtype                      <div title='object'>O</div>
# skew                                               NaN
# min_missing_partition                              NaN
# max_missing_partition                              NaN
# num_missing_partitions                             0.0
#
#                                         salary_in_usd  \
# perc_missing                                      0.0
# perc_zeros                                        0.0
# num_negative                                      0.0
# num_zeros                                         0.0
# perc_negative                                     0.0
# perc_distinct                                0.607908
# num_low_3x_IQR_outliers                           0.0
# num_high_3x_IQR_outliers                          1.0
# num_low_10x_IQR_outliers                          0.0
# num_high_10x_IQR_outliers                         0.0
# count                                             607
# n_unique                                          369
# decimal_col                                     False
# perc_most_freq                               0.024712
# val_most_freq                                  100000
# min                                            2859.0
# p05                                           20000.0
# p25                                           62726.0
# median                                       101570.0
# mean                                    112297.869852
# p75                                          150000.0
# p95                                          220110.0
# max                                          600000.0
# dtype                      <div title='int64'>I</div>
# skew                                         1.667545
# min_missing_partition                             NaN
# max_missing_partition                             NaN
# num_missing_partitions                            0.0
#
#                                     employee_residence  \
# perc_missing                                  0.210873
# perc_zeros                                         NaN
# num_negative                                       NaN
# num_zeros                                          NaN
# perc_negative                                      NaN
# perc_distinct                                 0.106472
# num_low_3x_IQR_outliers                            NaN
# num_high_3x_IQR_outliers                           NaN
# num_low_10x_IQR_outliers                           NaN
# num_high_10x_IQR_outliers                          NaN
# count                                              479
# n_unique                                            51
# decimal_col                                      False
# perc_most_freq                                0.559499
# val_most_freq                                       US
# min                                                NaN
# p05                                                NaN
# p25                                                NaN
# median                                             NaN
# mean                                               NaN
# p75                                                NaN
# p95                                                NaN
# max                                                NaN
# dtype                      <div title='object'>O</div>
# skew                                               NaN
# min_missing_partition                              1.0
# max_missing_partition                              1.0
# num_missing_partitions                             1.0
#
#                                          remote_ratio  \
# perc_missing                                      0.0
# perc_zeros                                   0.209226
# num_negative                                      0.0
# num_zeros                                       127.0
# perc_negative                                     0.0
# perc_distinct                                0.004942
# num_low_3x_IQR_outliers                           0.0
# num_high_3x_IQR_outliers                          0.0
# num_low_10x_IQR_outliers                          0.0
# num_high_10x_IQR_outliers                         0.0
# count                                             607
# n_unique                                            3
# decimal_col                                     False
# perc_most_freq                               0.627677
# val_most_freq                                     100
# min                                               0.0
# p05                                               0.0
# p25                                              50.0
# median                                          100.0
# mean                                         70.92257
# p75                                             100.0
# p95                                             100.0
# max                                             100.0
# dtype                      <div title='int64'>I</div>
# skew                                              NaN
# min_missing_partition                             NaN
# max_missing_partition                             NaN
# num_missing_partitions                            0.0
#
#                                       company_location  \
# perc_missing                                       0.0
# perc_zeros                                         NaN
# num_negative                                       NaN
# num_zeros                                          NaN
# perc_negative                                      NaN
# perc_distinct                                 0.082372
# num_low_3x_IQR_outliers                            NaN
# num_high_3x_IQR_outliers                           NaN
# num_low_10x_IQR_outliers                           NaN
# num_high_10x_IQR_outliers                          NaN
# count                                              607
# n_unique                                            50
# decimal_col                                      False
# perc_most_freq                                0.584843
# val_most_freq                                       US
# min                                                NaN
# p05                                                NaN
# p25                                                NaN
# median                                             NaN
# mean                                               NaN
# p75                                                NaN
# p95                                                NaN
# max                                                NaN
# dtype                      <div title='object'>O</div>
# skew                                               NaN
# min_missing_partition                              NaN
# max_missing_partition                              NaN
# num_missing_partitions                             0.0
#
#                                           company_size  \
# perc_missing                                       0.0
# perc_zeros                                         NaN
# num_negative                                       NaN
# num_zeros                                          NaN
# perc_negative                                      NaN
# perc_distinct                                 0.004942
# num_low_3x_IQR_outliers                            NaN
# num_high_3x_IQR_outliers                           NaN
# num_low_10x_IQR_outliers                           NaN
# num_high_10x_IQR_outliers                          NaN
# count                                              607
# n_unique                                             3
# decimal_col                                      False
# perc_most_freq                                0.537068
# val_most_freq                                        M
# min                                                NaN
# p05                                                NaN
# p25                                                NaN
# median                                             NaN
# mean                                               NaN
# p75                                                NaN
# p95                                                NaN
# max                                                NaN
# dtype                      <div title='object'>O</div>
# skew                                               NaN
# min_missing_partition                              NaN
# max_missing_partition                              NaN
# num_missing_partitions                             0.0
#
#                                           active_date
# perc_missing                                      0.0
# perc_zeros                                   0.197694
# num_negative                                      0.0
# num_zeros                                       120.0
# perc_negative                                     0.0
# perc_distinct                                0.008237
# num_low_3x_IQR_outliers                           0.0
# num_high_3x_IQR_outliers                          0.0
# num_low_10x_IQR_outliers                          0.0
# num_high_10x_IQR_outliers                         0.0
# count                                             607
# n_unique                                            5
# decimal_col                                     False
# perc_most_freq                               0.210873
# val_most_freq                                       1
# min                                               0.0
# p05                                               0.0
# p25                                               1.0
# median                                            2.0
# mean                                          1.98682
# p75                                               3.0
# p95                                               4.0
# max                                               4.0
# dtype                      <div title='int64'>I</div>
# skew                                              NaN
# min_missing_partition                             NaN
# max_missing_partition                             NaN
# num_missing_partitions                            NaN
